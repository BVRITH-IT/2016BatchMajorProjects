# %%
# load data
import pandas as pd
import numpy as np
import itertools

cancer=pd.read_csv('breast-cancer-w-diag.csv', header=0)
cancer.drop('id',axis=1,inplace=True)
cancer.drop('Unnamed: 32',axis=1,inplace=True)
cancer['diagnosis'] = cancer['diagnosis'].map({'M':1,'B':0})
cancer.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
cancer.shape
# Out:
# (569, 31)

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(cancer,test_size=0.2,random_state=0,stratify=cancer['diagnosis'])# stratify the outcome

# %%
train.shape
# Out:
# (455, 31)

# %%
test.shape
# Out:
# (114, 31)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(train.iloc[:,1:])
#df[['x','z']] = mms.fit_transform(df[['x','z']])
#train[train.columns[1:31]] = scaler.transform(train[train.columns[1:31]])
train.loc[:,1:] = scaler.transform(train.iloc[:,1:])
test.loc[:,1:] = scaler.transform(test.iloc[:,1:])

# %%
train.head()
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 381          0    -0.862083     -1.009094       -0.861347  -0.786765
# 144          0    -0.944093     -0.999941       -0.959931  -0.835771
# 136          0    -0.672612     -0.610936       -0.695675  -0.643408
# 116          0    -1.453119     -0.819168       -1.349362  -1.145863
# 567          1     1.841410      2.286005        1.978793   1.726355
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 381        -1.158494         -0.615198       -0.654171            -0.707010
# 144        -1.296173         -0.978211       -0.811038            -1.031182
# 136         0.632048         -0.799324       -0.648599            -0.574468
# 116        -0.111705          0.386082        0.038345            -0.648046
# 567         1.533350          3.243407        3.172896             2.600480
#
#      symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
test.head()
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 477          0    -0.053297     -0.622377       -0.112757  -0.148275
# 558          0     0.141829      0.764310        0.190769   0.014234
# 537          0    -0.678268      1.167045       -0.628180  -0.691851
# 322          0    -0.347401     -1.377504       -0.364332  -0.414712
# 474          0    -0.907330     -0.851204       -0.871982  -0.825632
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 477        -1.981021         -0.944529       -0.814308            -0.892215
# 558        -0.813586          0.548877        0.162748            -0.288219
# 537         1.944969          0.964284       -0.536793            -0.087895
# 322         1.221088         -0.286802       -0.623403            -0.372884
# 474         0.319785          0.060493       -0.464114            -0.833755
#
#      symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
train.to_csv("btrain.csv",header=False,index=False)
test.to_csv("btest.csv",header=False,index=False)
